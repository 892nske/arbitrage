# %%
import requests
import json

# %%
resp = requests.get("https://api.bybit.com/v5/market/tickers?category=inverse")
r=resp.json()

# %%
result=r['result']

# %%
list=result['list']

# %%
list
# Out:
# [{'symbol': 'ADAUSD',
#   'lastPrice': '0.4864',
#   'indexPrice': '0.4855',
#   'markPrice': '0.4862',
#   'prevPrice24h': '0.5025',
#   'price24hPcnt': '-0.032039',
#   'highPrice24h': '0.5100',
#   'lowPrice24h': '0.4824',
#   'prevPrice1h': '0.4878',
#   'openInterest': '11424972',
#   'openInterestValue': '23498502.67',
#   'turnover24h': '9270993.6939',
#   'volume24h': '4609153.0000',
#   'fundingRate': '0.00025235',
#   'nextFundingTime': '1716393600000',
#   'predictedDeliveryPrice': '',
#   'basisRate': '',
#   'deliveryFeeRate': '',
#   'deliveryTime': '0',
#   'ask1Size': '5923',
#   'bid1Price': '0.4863',
#   'ask1Price': '0.4864',
#   'bid1Size': '368',
#   'basis': ''},
#  {'symbol': 'BTCUSD',
#   'lastPrice': '70125.50',
#   'indexPrice': '70100.99',
#   'markPrice': '70125.50',
#   'prevPrice24h': '71226.50',
#   'price24hPcnt': '-0.015457',
#   'highPrice24h': '71494.00',
#   'lowPrice24h': '69160.00',
#   'prevPrice1h': '70118.00',
#   'openInterest': '966900572',
# ...

# %%
# シンボルにBTCを含むもののみを抽出
btc_symbols = [item for item in list if 'BTC' in item['symbol']]

print(btc_symbols)
# Out:
# [{'symbol': 'BTC-07JUN24', 'lastPrice': '70564.50', 'indexPrice': '70121.48', 'markPrice': '70559.83', 'prevPrice24h': '71604.50', 'price24hPcnt': '-0.014524', 'highPrice24h': '71839.50', 'lowPrice24h': '69584.50', 'prevPrice1h': '70476.00', 'openInterest': '2.398', 'openInterestValue': '169202.47', 'turnover24h': '140874.8755', 'volume24h': '1.9990', 'fundingRate': '', 'nextFundingTime': '0', 'predictedDeliveryPrice': '0.00', 'basisRate': '0.00606112', 'deliveryFeeRate': '0', 'deliveryTime': '1717747200000', 'ask1Size': '0.008', 'bid1Price': '70530.00', 'ask1Price': '70563.00', 'bid1Size': '0.008', 'basis': '443.0152'}, {'symbol': 'BTC-24MAY24', 'lastPrice': '70210.00', 'indexPrice': '70121.14', 'markPrice': '70211.71', 'prevPrice24h': '71236.00', 'price24hPcnt': '-0.014402', 'highPrice24h': '71579.50', 'lowPrice24h': '69256.00', 'prevPrice1h': '70155.50', 'openInterest': '111.522', 'openInterestValue': '7830150.32', 'turnover24h': '3594063.5375', 'volume24h': '51.1660', 'fundingRat
# ...

# %%
for list in result['list']:
    print(list['symbol'])
# Out:
# EOSUSDT
# MODEUSDT
# FLTUSDT
# MOVEZUSDT
# AXSUSDT
# USDCEUR
# XAIUSDT
# BTGUSDT
# WUSDT
# MELOSUSDT
# APEUSDT
# AEVOUSDT
# ONEUSDT
# QTUMUSDT
# GRAPEUSDT
# USDDUSDT
# SSVUSDT
# SCAUSDT
# DGBUSDT
# MIXUSDT
# FLIPUSDT
# ZEROUSDT
# DOTUSDT
# APTUSDC
# TUSDT
# STARUSDT
# XDCUSDT
# XECUSDT
# SUIUSDT
# KUBUSDT
# ARTYUSDT
# MKRUSDT
# SEILORUSDT
# METHUSDT
# 1SOLUSDT
# FARUSDT
# XRPUSDC
# PRIMALUSDT
# BLURUSDT
# ETHUSDT
# TAVAUSDT
# ETHUSDC
# MXMUSDT
# CTAUSDT
# DICEUSDT
# VPADUSDT
# FMBUSDT
# INJUSDT
# SUNUSDT
# MYRIAUSDT
# NEONUSDT
# TENETUSDT
# UMAUSDT
# DASHUSDT
# SHIBUSDC
# MXUSDT
# WEETHETH
# ORDIUSDT
# SQTUSDT
# USDYUSDT
# TAMAUSDT
# CBKUSDT
# RACAUSDT
# MOVRUSDT
# USDTEUR
# VRAUSDT
# SQDUSDT
# BRAWLUSDT
# BOBUSDT
# BTCUSDT
# COQUSDT
# TVKUSDT
# RSS3USDT
# VELAUSDT
# SEIUSDT
# COREUSDT
# DRIFTUSDT
# BNBUSDT
# SHRAPUSDT
# BCHUSDT
# POLUSDT
# PENDLEUSDT
# TUSDUSDT
# LTCUSDT
# ALTUSDT
# MYROUSDT
# MLKUSDT
# FORTUSDT
# QORPOUSDT
# DPXUSDT
# MVUSDT
# COMPUSDT
# HOTUSDT
# MCRTUSDT
# ...
